# %% [markdown]
# # CSC420 Assignment 3 Question 1

# %%
import matplotlib.pyplot as plt
import scipy
import cv2
import numpy as np

# %% [markdown]
# ## Set up parameters

# %%
size = 1000
sigma = 100
mid = int(size/2)
center_coord = (mid, mid)
thickness = -1
radius = 100

# %% [markdown]
# ## Question 1A Generate all white background

# %%
all_white = 255 * np.ones(shape=(size, size,), dtype=np.uint8)
white_bg_with_black_circ = cv2.circle(all_white, center_coord, radius, color=0, thickness=-1)
# Unclip it
unclipped = np.array(white_bg_with_black_circ, dtype=float)

# %%
rslt = scipy.ndimage.gaussian_laplace(unclipped, sigma=sigma)

array = np.array(list(rslt))

print(sigma)
plt.plot(list(range(size)), array[mid])
plt.title("Center-slice of the image with sigma " + str(sigma)+ ' and radius ' + str(radius))
plt.show()

plt.imshow(rslt)
plt.title("Image with sigma " + str(sigma) + ' and radius ' + str(radius))
plt.show()
# Out:
# 100

# %% [markdown]
# ## Question 1B

# %%
all_black = np.zeros(shape=(size, size,), dtype=np.uint8)

black_bg_with_white_circ = cv2.circle(all_black, center_coord, radius, color=255, thickness=-1)

unclipped = np.array(black_bg_with_white_circ, dtype=float)

rslt = scipy.ndimage.gaussian_laplace(unclipped, sigma=sigma)

array = np.array(list(rslt))

print(sigma)
plt.plot(list(range(size)), array[mid])
plt.title("Center-slice of the image with sigma " + str(sigma)+ ' and radius ' + str(radius))
plt.show()

plt.imshow(rslt)
plt.title("Image with sigma " + str(sigma) + ' and radius ' + str(radius))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [6], line 7
#       3 black_bg_with_white_circ = cv2.circle(all_black, center_coord, radius, color=255, thickness=-1)
#       5 unclipped = np.array(black_bg_with_white_circ, dtype=float)
# ----> 7 rslt = scipy.ndimage.gaussian_laplace(unclipped, sigma=sigma)
#       9 array = np.array(list(rslt))
#      11 print(sigma)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/scipy/ndimage/_filters.py:539, in gaussian_laplace(input, sigma, output, mode, cval, **kwargs)
#     535     order[axis] = 2
#     536     return gaussian_filter(input, sigma, order, output, mode, cval,
#     537                            **kwargs)
# --> 539 return generic_laplace(input, derivative2, output, mode, cval,
#     540                        extra_arguments=(sigma,),
#     541                        extra_keywords=kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/scipy/ndimage/_filters.py:455, in generic_laplace(input, derivative2, output, mode, cval, extra_arguments, extra_keywords)
#     453 if len(axes) > 0:
#     454     modes = _ni_support._normalize_sequence(mode, len(axes))
# --> 455     derivative2(input, axes[0], output, modes[0], cval,
#     456                 *extra_arguments, **extra_keywords)
#     457     for ii in range(1, len(axes)):
#     458         tmp = derivative2(input, axes[ii], output.dtype, modes[ii], cval,
#     459                           *extra_arguments, **extra_keywords)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/scipy/ndimage/_filters.py:536, in gaussian_laplace.<locals>.derivative2(input, axis, output, mode, cval, sigma, **kwargs)
#     534 order = [0] * input.ndim
#     535 order[axis] = 2
# --> 536 return gaussian_filter(input, sigma, order, output, mode, cval,
#     537                        **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/scipy/ndimage/_filters.py:342, in gaussian_filter(input, sigma, order, output, mode, cval, truncate)
#     340 if len(axes) > 0:
#     341     for axis, sigma, order, mode in axes:
# --> 342         gaussian_filter1d(input, sigma, axis, order, output,
#     343                           mode, cval, truncate)
#     344         input = output
#     345 else:
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/scipy/ndimage/_filters.py:261, in gaussian_filter1d(input, sigma, axis, order, output, mode, cval, truncate)
#     259 # Since we are calling correlate, not convolve, revert the kernel
#     260 weights = _gaussian_kernel1d(sigma, order, lw)[::-1]
# --> 261 return correlate1d(input, weights, axis, output, mode, cval, 0)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/scipy/ndimage/_filters.py:133, in correlate1d(input, weights, axis, output, mode, cval, origin)
#     129     raise ValueError('Invalid origin; origin must satisfy '
#     130                      '-(len(weights) // 2) <= origin <= '
#     131                      '(len(weights)-1) // 2')
#     132 mode = _ni_support._extend_mode_to_code(mode)
# --> 133 _nd_image.correlate1d(input, weights, axis, output, mode, cval,
#     134                       origin)
#     135 return output
#
# KeyboardInterrupt:
